# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/content/drive/MyDrive/DS/adult.data",index_col= False)

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
df.columns = ["Age", "Workclass","Fnlwgt", "Education","education-num","marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country","income" ]

# %%
df
# Out:
#        Age          Workclass  ...  native-country Listing of attributes
# 0       50   Self-emp-not-inc  ...   United-States                 <=50K
# 1       38            Private  ...   United-States                 <=50K
# 2       53            Private  ...   United-States                 <=50K
# 3       28            Private  ...            Cuba                 <=50K
# 4       37            Private  ...   United-States                 <=50K
# ...    ...                ...  ...             ...                   ...
# 32555   27            Private  ...   United-States                 <=50K
# 32556   40            Private  ...   United-States                  >50K
# 32557   58            Private  ...   United-States                 <=50K
# 32558   22            Private  ...   United-States                 <=50K
# 32559   52       Self-emp-inc  ...   United-States                  >50K
#
# [32560 rows x 15 columns]
# Warning: total number of rows (32560) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
df.to_csv("ds.csv")

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  ...  capital-loss  hours-per-week
# count  32560.000000  3.256000e+04  ...  32560.000000    32560.000000
# mean      38.581634  1.897818e+05  ...     87.306511       40.437469
# std       13.640642  1.055498e+05  ...    402.966116       12.347618
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178315e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783630e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370545e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  ...  capital-loss  hours-per-week
# Age             1.000000 -0.076646  ...      0.057775        0.068756
# Fnlwgt         -0.076646  1.000000  ...     -0.010259       -0.018770
# education-num   0.036527 -0.043159  ...      0.079932        0.148127
# capital-gain    0.077674  0.000437  ...     -0.031614        0.078409
# capital-loss    0.057775 -0.010259  ...      1.000000        0.054256
# hours-per-week  0.068756 -0.018770  ...      0.054256        1.000000
#
# [6 rows x 6 columns]

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
colormap = sns.color_palette("Greens")
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap= colormap)

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(df.Workclass)
df['work_class'] = le.transform(df.Workclass)

# %%
df
# Out:
#        Age          Workclass  ...  Listing of attributes work_class
# 0       50   Self-emp-not-inc  ...                  <=50K          6
# 1       38            Private  ...                  <=50K          4
# 2       53            Private  ...                  <=50K          4
# 3       28            Private  ...                  <=50K          4
# 4       37            Private  ...                  <=50K          4
# ...    ...                ...  ...                    ...        ...
# 32555   27            Private  ...                  <=50K          4
# 32556   40            Private  ...                   >50K          4
# 32557   58            Private  ...                  <=50K          4
# 32558   22            Private  ...                  <=50K          4
# 32559   52       Self-emp-inc  ...                   >50K          5
#
# [32560 rows x 16 columns]
